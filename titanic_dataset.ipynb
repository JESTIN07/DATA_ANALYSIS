# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv(r'C:\Users\jesti\OneDrive\Desktop\arcite\Titanic-Dataset.csv',nrows=10)

# %%
data
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data.tail()
# Out:
#    PassengerId  Survived  Pclass  \
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch  Ticket     Fare Cabin Embarked
# 5      0  330877   8.4583   NaN        Q
# 6      0   17463  51.8625   E46        S
# 7      1  349909  21.0750   NaN        S
# 8      2  347742  11.1333   NaN        S
# 9      0  237736  30.0708   NaN        C

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.columns[1:4]
# Out:
# Index(['Survived', 'Pclass', 'Name'], dtype='object')

# %%
data.T
# Out:
#                                    0  \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                             22.0
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                              1  \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                       38.0
# ...

# %%
data.axes[1]
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.iloc[10:20]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
data.values
# Out:
# array([[1, 0, 3, 'Braund, Mr. Owen Harris', 'male', 22.0, 1, 0,
#         'A/5 21171', 7.25, nan, 'S'],
#        [2, 1, 1, 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#         'female', 38.0, 1, 0, 'PC 17599', 71.2833, 'C85', 'C'],
#        [3, 1, 3, 'Heikkinen, Miss. Laina', 'female', 26.0, 0, 0,
#         'STON/O2. 3101282', 7.925, nan, 'S'],
#        [4, 1, 1, 'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#         'female', 35.0, 1, 0, '113803', 53.1, 'C123', 'S'],
#        [5, 0, 3, 'Allen, Mr. William Henry', 'male', 35.0, 0, 0,
#         '373450', 8.05, nan, 'S'],
#        [6, 0, 3, 'Moran, Mr. James', 'male', nan, 0, 0, '330877', 8.4583,
#         nan, 'Q'],
#        [7, 0, 1, 'McCarthy, Mr. Timothy J', 'male', 54.0, 0, 0, '17463',
#         51.8625, 'E46', 'S'],
#        [8, 0, 3, 'Palsson, Master. Gosta Leonard', 'male', 2.0, 3, 1,
#         '349909', 21.075, nan, 'S'],
#        [9, 1, 3, 'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
data.shape
# Out:
# (10, 12)

# %%
data.size
# Out:
# 120

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  10 non-null     int64
#  1   Survived     10 non-null     int64
#  2   Pclass       10 non-null     int64
#  3   Name         10 non-null     object
#  4   Sex          10 non-null     object
#  5   Age          9 non-null      float64
#  6   SibSp        10 non-null     int64
#  7   Parch        10 non-null     int64
#  8   Ticket       10 non-null     object
#  9   Fare         10 non-null     float64
#  10  Cabin        3 non-null      object
#  11  Embarked     10 non-null     object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 1.1+ KB

# %%
data.ndim
# Out:
# 2

# %%
data.set_index
# Out:
# <bound method DataFrame.set_index of    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data["Name"]
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
data[['Name','Survived','Sex']]
# Out:
#                                                 Name  Survived     Sex
# 0                            Braund, Mr. Owen Harris         0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1  female
# 2                             Heikkinen, Miss. Laina         1  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1  female
# 4                           Allen, Mr. William Henry         0    male
# 5                                   Moran, Mr. James         0    male
# 6                            McCarthy, Mr. Timothy J         0    male
# 7                     Palsson, Master. Gosta Leonard         0    male
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1  female
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1  female

# %%
data.value_counts('Survived')
# Out:
# Survived
# 0    5
# 1    5
# Name: count, dtype: int64

# %%
data.value_counts('Sex')
# Out:
# Sex
# female    5
# male      5
# Name: count, dtype: int64

# %%
data.groupby('Survived')["Sex"].count()
# Out:
# Survived
# 0    5
# 1    5
# Name: Sex, dtype: int64

# %%
data.iloc[5:8:2]["Age"]
# Out:
# 5    NaN
# 7    2.0
# Name: Age, dtype: float64

# %%
sns.barplot(x=data.value_counts('survived').index,y=data.value_counts('survived').values)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 sns.barplot(x=data.value_counts('survived').index,y=data.value_counts('survived').values)
#
# File c:\Users\jesti\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:7509, in DataFrame.value_counts(self, subset, normalize, sort, ascending, dropna)
#    7505         if subset is None:
#    7506             subset = self.columns.tolist()
#    7507
#    7508         name = "proportion" if normalize else "count"
# -> 7509         counts = self.groupby(subset, dropna=dropna, observed=False)._grouper.size()
#    7510         counts.name = name
#    7511
#    7512         if sort:
#
# File c:\Users\jesti\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
# ...

# %%
sns.countplot(data=data,x='survived')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(data=data,x='sex',hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
k=[]
for i in data.columns:
   k.append( i.lower())

# %%
k
# Out:
# ['passengerid',
#  'survived',
#  'pclass',
#  'name',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'ticket',
#  'fare',
#  'cabin',
#  'embarked']

# %%
data.columns=k

# %%
data
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data[data['sex']=='male']['survived']
# Out:
# 0    0
# 4    0
# 5    0
# 6    0
# 7    0
# Name: survived, dtype: int64

# %%
data['age'].max()
# Out:
# np.float64(54.0)

# %%
data['age'].min()
# Out:
# np.float64(2.0)

# %%
data['age'].mean()
# Out:
# np.float64(28.11111111111111)

# %%
data[data['age']>20]
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 6            7         0       1
# 8            9         1       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    parch            ticket     fare cabin embarked
# ...

# %%
data[(data['age'] > 20) & (data['age'] < 30)]
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 2            3         1       3
# 8            9         1       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 8      2            347742  11.1333   NaN        S

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv(r'C:\Users\jesti\OneDrive\Desktop\arcite\Titanic-Dataset.csv')
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data1.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data1.columns[1:10]
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare'],
#       dtype='object')

# %%
sns.countplot(data=data.head(20), x='sex', hue='survived')
plt.title('Titanic Survival by Gender', fontsize=14, fontweight='bold')
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.legend(title='Survived', labels=['No', 'Yes'])

# %%
sns.boxplot(data=data,x='age')
# Out:
# <Axes: xlabel='age'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   passengerid  10 non-null     int64
#  1   survived     10 non-null     int64
#  2   pclass       10 non-null     int64
#  3   name         10 non-null     object
#  4   sex          10 non-null     object
#  5   age          9 non-null      float64
#  6   sibsp        10 non-null     int64
#  7   parch        10 non-null     int64
#  8   ticket       10 non-null     object
#  9   fare         10 non-null     float64
#  10  cabin        3 non-null      object
#  11  embarked     10 non-null     object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 1.1+ KB

# %%
data.isna().sum()
# Out:
# passengerid    0
# survived       0
# pclass         0
# name           0
# sex            0
# age            1
# sibsp          0
# parch          0
# ticket         0
# fare           0
# cabin          7
# embarked       0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.groupby('sex')['age'].mean()
# Out:
# sex
# female    28.00
# male      28.25
# Name: age, dtype: float64

# %%
data[(data['age'] > 20) & (data['age'] < 30)][['name','sex']]
# Out:
#                                                 name     sex
# 0                            Braund, Mr. Owen Harris    male
# 2                             Heikkinen, Miss. Laina  female
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female

# %%
data.drop(['passengerid','ticket'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[213], line 1
# ----> 1 data.drop(['passengerid','ticket'],axis=1,inplace=True)
#
# File c:\Users\jesti\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
# ...

# %%
data
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       sex   age  sibsp  parch     fare cabin embarked
# 0    male  22.0      1      0   7.2500   NaN        S
# 1  female  38.0      1      0  71.2833   C85        C
# ...

# %%
data['number']=data['sex'].map(lambda x: 0 if x == 'male'  else 1 )

# %%
data
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       sex   age  sibsp  parch     fare cabin embarked  number
# 0    male  22.0      1      0   7.2500   NaN        S       0
# 1  female  38.0      1      0  71.2833   C85        C       1
# ...

# %%
data2 = pd.DataFrame({'angles': [0, 3, 4],
                   'degrees': [360, 180, 360]},
                  index=['circle', 'triangle', 'rectangle'])
data2
# Out:
#            angles  degrees
# circle          0      360
# triangle        3      180
# rectangle       4      360

# %%
data2.div(10)
# Out:
#            angles  degrees
# circle        0.0     36.0
# triangle      0.3     18.0
# rectangle     0.4     36.0

# %%
data2.add(1000)
# Out:
#            angles  degrees
# circle       1000     1360
# triangle     1003     1180
# rectangle    1004     1360

# %%
data['fare']=data['fare'].add(200)
data
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       sex   age  sibsp  parch       fare cabin embarked  number
# 0    male  22.0      1      0  1807.2500   NaN        S       0
# ...

# %%
df = pd.DataFrame([[0, 1, -2, -1], [1, 1, 1, 1]])
s = pd.Series([1, 1, 2, 1])
df.dot(s)
# Out:
# 0   -4
# 1    5
# dtype: int64

# %%
df = pd.DataFrame(
    [
        [24.3, 75.7, "high"],
        [31, 87.8, "high"],
        [22, 71.6, "medium"],
        [35, 95, "medium"],
    ],
    columns=["temp_celsius", "temp_fahrenheit", "windspeed"],
    index=pd.date_range(start="2014-02-12", end="2014-02-15", freq="D"),
)
df
df.get(["temp_celsius", "windspeed"])
# Out:
#             temp_celsius windspeed
# 2014-02-12          24.3      high
# 2014-02-13          31.0      high
# 2014-02-14          22.0    medium
# 2014-02-15          35.0    medium

# %%
data.get(["name","survived","fare"])
# Out:
#                                                 name  survived       fare
# 0                            Braund, Mr. Owen Harris         0  1807.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1  1871.2833
# 2                             Heikkinen, Miss. Laina         1  1807.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1  1853.1000
# 4                           Allen, Mr. William Henry         0  1808.0500
# 5                                   Moran, Mr. James         0  1808.4583
# 6                            McCarthy, Mr. Timothy J         0  1851.8625
# 7                     Palsson, Master. Gosta Leonard         0  1821.0750
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1  1811.1333
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1  1830.0708

# %%
df = pd.DataFrame(
    {
        "Animal": ["Falcon", "Falcon", "Parrot", "Parrot"],
        "Max Speed": [380.0, 370.0, 24.0, 26.0],
    }
)
print(df)
df.groupby(['Animal']).mean()
# Out:
#    Animal  Max Speed
# 0  Falcon      380.0
# 1  Falcon      370.0
# 2  Parrot       24.0
# 3  Parrot       26.0
#         Max Speed
# Animal
# Falcon      375.0
# Parrot       25.0

# %%
x=data.groupby('sex')['survived'].mean()
sns.boxplot(data=data,x=x)
# Out:
# <Axes: xlabel='survived'>

# %%
sns.histplot(data=data,x='age')
# data['age'].hist(bins=20, edgecolor='black', grid=False)
plt.title('Distribution of Passenger Ages on the Titanic')
plt.xlabel('Age (Years)')
plt.ylabel('Number of Passengers')
plt.show()

# %%
data.idxmax(numeric_only=True)
# Out:
# survived    1
# pclass      0
# age         6
# sibsp       7
# parch       8
# fare        1
# number      1
# dtype: int64

# %%
data.iloc[6]['name']
# Out:
# 'McCarthy, Mr. Timothy J'

# %%
data.idxmin(numeric_only=True)
# Out:
# survived    0
# pclass      1
# age         7
# sibsp       2
# parch       0
# fare        0
# number      0
# dtype: int64

# %%
data.iloc[7]
# Out:
# survived                                 0
# pclass                                   3
# name        Palsson, Master. Gosta Leonard
# sex                                   male
# age                                    2.0
# sibsp                                    3
# parch                                    1
# fare                              1821.075
# cabin                                  NaN
# embarked                                 S
# number                                   0
# Name: 7, dtype: object

# %%
data.insert(loc=4 ,column='bn', value=data['sex'].map(lambda x: 0 if x == 'male'  else 1 ))

# %%
data
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 5         0       3                                   Moran, Mr. James
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
# 8         1       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1       2                Nasser, Mrs. Nicholas (Adele Achem)
#
#       sex  bn   age  sibsp  parch       fare cabin embarked  number
# 0    male   0  22.0      1      0  1807.2500   NaN        S       0
# ...

# %%
for i in data.columns:
    print(i)
# Out:
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked

# %%
data.values[1:3]
# Out:
# array([[2, 1, 1, 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#         'female', 38.0, 1, 0, 'PC 17599', 71.2833, 'C85', 'C'],
#        [3, 1, 3, 'Heikkinen, Miss. Laina', 'female', 26.0, 0, 0,
#         'STON/O2. 3101282', 7.925, nan, 'S']], dtype=object)

# %%
avg_fare = data['Fare'].mean()
print(f"Average Fare: ${avg_fare:.2f}")

avg_age = data['Age'].mean()
print(f"Average Age : {avg_age:.0f} years")
# Out:
# Average Fare: $27.02
# Average Age : 28 years

# %%
min_age = data['Age'].min()
print(f"Minimum Age : {min_age:.0f} years")

max_age = data['Age'].max()
print(f"Maximum Age : {max_age:.0f} years")
# Out:
# Minimum Age : 2 years

# %%
min_fare = data['Fare'].min()
print(f"Minimum Fare : ${min_fare:.2f}")

max_fare = data['Fare'].max()
print(f"Maximum Fare : ${max_fare:.2f}")
# Out:
# Minimum Fare : $7.25
# Maximum Fare : $71.28

# %%
data.describe()
# Out:
#        PassengerId   Survived     Pclass        Age      SibSp      Parch  \
# count     10.00000  10.000000  10.000000   9.000000  10.000000  10.000000
# mean       5.50000   0.500000   2.300000  28.111111   0.700000   0.300000
# std        3.02765   0.527046   0.948683  14.945271   0.948683   0.674949
# min        1.00000   0.000000   1.000000   2.000000   0.000000   0.000000
# 25%        3.25000   0.000000   1.250000  22.000000   0.000000   0.000000
# 50%        5.50000   0.500000   3.000000  27.000000   0.500000   0.000000
# 75%        7.75000   1.000000   3.000000  35.000000   1.000000   0.000000
# max       10.00000   1.000000   3.000000  54.000000   3.000000   2.000000
#
#             Fare
# count  10.000000
# mean   27.020820
# std    23.601938
# min     7.250000
# 25%     8.152075
# 50%    16.104150
# 75%    46.414575
# max    71.283300

# %%
data.describe(include='number')
# Out:
#        PassengerId   Survived     Pclass        Age      SibSp      Parch  \
# count     10.00000  10.000000  10.000000   9.000000  10.000000  10.000000
# mean       5.50000   0.500000   2.300000  28.111111   0.700000   0.300000
# std        3.02765   0.527046   0.948683  14.945271   0.948683   0.674949
# min        1.00000   0.000000   1.000000   2.000000   0.000000   0.000000
# 25%        3.25000   0.000000   1.250000  22.000000   0.000000   0.000000
# 50%        5.50000   0.500000   3.000000  27.000000   0.500000   0.000000
# 75%        7.75000   1.000000   3.000000  35.000000   1.000000   0.000000
# max       10.00000   1.000000   3.000000  54.000000   3.000000   2.000000
#
#             Fare
# count  10.000000
# mean   27.020820
# std    23.601938
# min     7.250000
# 25%     8.152075
# 50%    16.104150
# 75%    46.414575
# max    71.283300

# %%
data.describe(exclude='number')
# Out:
#                            Name   Sex     Ticket Cabin Embarked
# count                        10    10         10     3       10
# unique                       10     2         10     3        3
# top     Braund, Mr. Owen Harris  male  A/5 21171   C85        S
# freq                          1     5          1     1        7

# %%
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
data.shape
# Out:
# (10, 12)

# %%
data.isna()
# Out:
#    PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0        False     False   False  False  False  False  False  False   False
# 1        False     False   False  False  False  False  False  False   False
# 2        False     False   False  False  False  False  False  False   False
# 3        False     False   False  False  False  False  False  False   False
# 4        False     False   False  False  False  False  False  False   False
# 5        False     False   False  False  False   True  False  False   False
# 6        False     False   False  False  False  False  False  False   False
# 7        False     False   False  False  False  False  False  False   False
# 8        False     False   False  False  False  False  False  False   False
# 9        False     False   False  False  False  False  False  False   False
#
#     Fare  Cabin  Embarked
# 0  False   True     False
# 1  False  False     False
# 2  False   True     False
# ...

# %%
data.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            1
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          7
# Embarked       0
# dtype: int64

# %%
data.dropna(inplace=False)
data.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
data[data['Age'] > 30]["Sex"]
# Out:
# 1    female
# 3    female
# 6      male
# Name: Sex, dtype: object

# %%
data1 = pd.read_csv(r'C:\Users\jesti\OneDrive\Desktop\arcite\Titanic-Dataset.csv')
data1[(data1['Age'] > 30) & (data1['Sex'] == 'male')]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 4              5         0       3              Allen, Mr. William Henry
# 6              7         0       1               McCarthy, Mr. Timothy J
# 13            14         0       3           Andersson, Mr. Anders Johan
# 20            21         0       2                  Fynney, Mr. Joseph J
# 21            22         1       2                 Beesley, Mr. Lawrence
# ..           ...       ...     ...                                   ...
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
# 873          874         0       3           Vander Cruyssen, Mr. Victor
# 881          882         0       3                    Markun, Mr. Johann
# 890          891         0       3                   Dooley, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare        Cabin Embarked
# ...

# %%
data1.iloc[100]
# Out:
# PassengerId                        101
# Survived                             0
# Pclass                               3
# Name           Petranec, Miss. Matilda
# Sex                             female
# Age                               28.0
# SibSp                                0
# Parch                                0
# Ticket                          349245
# Fare                            7.8958
# Cabin                              NaN
# Embarked                             S
# Name: 100, dtype: object

# %%
data1.iloc[[100]]
# Out:
#      PassengerId  Survived  Pclass                     Name     Sex   Age  \
# 100          101         0       3  Petranec, Miss. Matilda  female  28.0
#
#      SibSp  Parch  Ticket    Fare Cabin Embarked
# 100      0      0  349245  7.8958   NaN        S

# %%
data1.iloc[20:100:2]
# Out:
#     PassengerId  Survived  Pclass  \
# 20           21         0       2
# 22           23         1       3
# 24           25         0       3
# 26           27         0       3
# 28           29         1       3
# 30           31         0       1
# 32           33         1       3
# 34           35         0       1
# 36           37         1       3
# 38           39         0       3
# 40           41         0       3
# 42           43         0       3
# 44           45         1       3
# 46           47         0       3
# 48           49         0       3
# 50           51         0       3
# 52           53         1       1
# 54           55         0       1
# 56           57         1       2
# 58           59         1       2
# 60           61         0       3
# 62           63         0       1
# 64           65         0       1
# 66           67         1       2
# 68           69         1       3
# 70           71         0       2
# ...

# %%
data1.iloc[[1, 2, 3, 4]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data1[~((data1['Age'] > 30) & (data1['Sex'] == 'male'))]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 5              6         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1.iloc[lambda x: x.index % 2 == 0]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 882          883         0       3
# 884          885         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1.loc[lambda x: x['Age'] > 30]['Age']
# Out:
# 1      38.0
# 3      35.0
# 4      35.0
# 6      54.0
# 11     58.0
#        ...
# 873    47.0
# 879    56.0
# 881    33.0
# 885    39.0
# 890    32.0
# Name: Age, Length: 305, dtype: float64

# %%
data1.loc[lambda x: x['Age'] > 30]['Age']=0
data1['Age']
# Out:
# C:\Users\jesti\AppData\Local\Temp\ipykernel_28612\3741376060.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.loc[lambda x: x['Age'] > 30]['Age']=0
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
data1.iloc[[0, 2],[1, 3]]
# Out:
#    Survived                     Name
# 0         0  Braund, Mr. Owen Harris
# 2         1   Heikkinen, Miss. Laina

# %%
data1.iloc[1:3, 0:3]
# Out:
#    PassengerId  Survived  Pclass
# 1            2         1       1
# 2            3         1       3

# %%
data1.loc[data1["Age"] > 50]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 54            55         0       1
# ..           ...       ...     ...
# 820          821         1       1
# 829          830         1       1
# 851          852         0       3
# 857          858         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 54                      Ostby, Mr. Engelhart Cornelius    male  65.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data1.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
for i in data1.columns:
    
    if data1[i].dtype == 'object':
        data1[i] = data1[i].fillna(data1[i].mode()[0])
    
    else:
        data1[i] = data1[i].fillna(data1[i].median())

data1.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64
